# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

class compareImg :
    def __init__(self) :
        pass
 
    def readImg(self, filepath) :
        img = cv2.imread(filepath, cv2.IMREAD_GRAYSCALE)
        #cv2.namedWindow("root", cv2.WINDOW_NORMAL) # window 생성
        #cv2.imshow("root", img) # window에 이미지 띄우기
        #cv2.waitKey(5000) # 5초 기다림. 아무키나 입력되면 대기 종료
        #cv2.destroyAllWindows() # window 제거
        return img
 
 
    def diffImg(self, img1, img2) :
        # Initiate SIFT detector
        orb = cv2.ORB_create()
 
        # find the keypoints and descriptors with SIFT
        kp1, des1 = orb.detectAndCompute(img1, None)
        kp2, des2 = orb.detectAndCompute(img2, None)
 
        # create BFMatcher object
        bf = cv2.BFMatcher(cv2.NORM_HAMMING, crossCheck=True)
 
        # Match descriptors.
        matches = bf.match(des1,des2)
 
        # Sort them in the order of their distance.
        matches = sorted(matches, key = lambda x:x.distance)
 
        # BFMatcher with default params
        bf = cv2.BFMatcher()
        matches = bf.knnMatch(des1, des2, k=2)
 
        # Apply ratio test
        good = []
        for m,n in matches:
            if m.distance < 0.75 * n.distance:
                good.append([m])
 
        # Draw first 10 matches.
        knn_image = cv2.drawMatchesKnn(img1, kp1, img2, kp2, good, None, flags=2)
        plt.imshow(knn_image, aspect='auto',interpolation='nearest')
        plt.show()
        
 
    def run(self) :
        # 이미지 파일 경로 설정
        filepath1 = r"C:\Users\dlgpd\fontProject\itary.png"
        filepath2 = r"C:\Users\dlgpd\fontProject\python\2.png"
        
        # 이미지 객체 가져옴
        img1 = self.readImg(filepath1)
        img2 = self.readImg(filepath2)
 
        # 2개의 이미지 비교
        self.diffImg(img1, img2)
 
if __name__ == '__main__':
    cImg = compareImg()
    cImg.run()

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt
 
img1 = cv2.imread(r"C:\Users\dlgpd\fontProject\itary.png",0)
img2 = cv2.imread(r"C:\Users\dlgpd\fontProject\python\2.png",0)
 
orb = cv2.ORB_create()
 
kp1, des1 = orb.detectAndCompute(img1,None)
kp2, des2 = orb.detectAndCompute(img2,None)
 
bf = cv2.BFMatcher(cv2.NORM_HAMMING, crossCheck=True)
 
matches = bf.match(des1,des2)
 
matches = sorted(matches, key = lambda x:x.distance)

print(matches[:10])

img3 = cv2.drawMatches(img1,kp1,img2,kp2,matches[:10],None,flags=2)
 
plt.imshow(img3,aspect='auto',interpolation='nearest'),plt.show()
# Out:
# [<DMatch 000002669845D130>, <DMatch 000002669CE457D0>, <DMatch 000002669CE45B10>, <DMatch 000002669CE45C90>, <DMatch 000002669CE458D0>, <DMatch 000002669CE45A50>, <DMatch 000002669CE45970>, <DMatch 000002669CE45D30>, <DMatch 000002669CE45B50>, <DMatch 000002669CE45B90>]
# (<matplotlib.image.AxesImage at 0x2669d1ea0b8>, None)

# %%
a = '<DMatch 000002669845D130>'
print(a[16:-1])
# Out:
# 9845D130

# %%
print(000002669CE45F70 > 000002669CE45F50)
# Out:
#   File "<ipython-input-52-48bde0e6f6dc>", line 1
#     print(000002669CE45F70 > 000002669CE45F50)
#                   ^
# SyntaxError: invalid token

# %%
help(cv2.BFMatcher)
# Out:
# Help on class BFMatcher in module cv2.cv2:
#
# class BFMatcher(DescriptorMatcher)
#  |  Method resolution order:
#  |      BFMatcher
#  |      DescriptorMatcher
#  |      Algorithm
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, /, *args, **kwargs)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __repr__(self, /)
#  |      Return repr(self).
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods defined here:
#  |
#  |  __new__(*args, **kwargs) from builtins.type
#  |      Create and return a new object.  See help(type) for accurate signature.
#  |
#  |  create(...)
#  |      create([, normType[, crossCheck]]) -> retval
#  |      .   @brief Brute-force matcher create method.
#  |      .   @param normType One of NORM_L1, NORM_L2, NORM_HAMMING, NORM_HAMMING2. L1 and L2 norms are
# ...

# %%
min_dictionary = {}
max_dictionary = {}
everageOfDictionary = {}

def eachSimilar(fontname)
 
 matches = bf.match()
 min_dictionary[name] = min(matches)
 max_dictionary[name] = max(matches)
normal_matches = matches [3 : ]
del normal_matches[2:]
 everageOfDictionary[name] = sum(matches)/len(matches)


def judge():
    fontOfMax = max(max_dictionary.keys(), key=f1)
    fontOfMin = min(min_dictionary.keys(), key=(lambda k: my_dict[k]))
    mineverageFont = min(min_dictionary.keys(), key=(lambda k: my_dict[k]))
    
    print('in max of distance,' + fontOfMax + 'is shortest')
    print('in min of distance,' + fontOfmin + 'is shortest')
    print('in everage,' + mineverageFont + 'is shortest')
    a = 'd'
    b = 'c'
    if

# %%
from collections import Counter
a = 'A'
b = ''
c = 'B'

list = []
list.append(a)
list.append(b)
list.append(c)
print(list)


myList =  [1, 2, 3, 4, 1, 4, 1]

print ("---Counter()---")
result = Counter(list)
print(result)

t = 0
if a == b:
    t+=1
elif a !=b:
    t-=1
elif b == c:
    t+=1
elif b !=c:
    t-=1
elif c == a:
    t+=1
elif c !=a:
    t-=1
    
print(t)
# Out:
# ['A', 'B', 'B']
# ---Counter()---
# Counter({'B': 2, 'A': 1})
# -1

# %%
try:
    from PIL import Image
except mportError:
    import Image 
import numpy as np    
import pytesseract
import cv2
from matplotlib import pyplot as plt

pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract'
targerImg = pytesseract.pytesseract.tesseract_cmd

text = pytesseract.image_to_string(Image.open(r'C:\Users\dlgpd\fontProject\itary.png'))
print(text)
# Out:
# Dasom

# %%
def transformNum(num):
    num = str(num)
    num = num[16:-1]
    return int(num, 16)

print(transformNum(matches[0]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-01828ef4e222> in <module>
#       4     return int(num, 16)
#       5
# ----> 6 print(transformNum(matches[0]))
#
# NameError: name 'matches' is not defined

# %%
transformed = []
    
for i in range(10):
    transformed.append(transformNum(matches[i]))
    
print(transformed)

# %%
fontlist = ['cv2.FONT_HERSHEY_DUPLE', 'cv2.FONT_HERSHEY_TRIPLEX', 'cv2.FONT_ITALIC']
min_dictionary = {}
max_dictionary = {}
everageOfDictionary = {}

def makeImage(name):
    img_w = 300
    img_h = 200
    bpp = 3

    img = np.zeros((img_h, img_w, bpp), np.uint8)
    img.fill(255)

    black = (0,0,0)


    center_x = int(img_w / 2.0)
    center_y = int(img_h / 2.0)


    thickness = 1


    location = (center_x, center_y)
    font = name  # normal size serif font
    fontScale = 1.3
    cv2.putText(img, 'Dasom', location, font, fontScale, black, thickness)

    return img

# %%
img1 = cv2.imread(r'C:\Users\dlgpd\fontProject\duplex.png',0)
cv2.imshow("image", img1)
cv2.waitKey(0)
# Out:
# -1

# %%
def matchingInfo(img):
    img1 = cv2.imread(r'C:\Users\dlgpd\fontProject\duplex.png',0)
    img2 = img
    
    orb = cv2.ORB_create()
 
    kp1, des1 = orb.detectAndCompute(img1,None)
    kp2, des2 = orb.detectAndCompute(img2,None)
 
    bf = cv2.BFMatcher(cv2.NORM_HAMMING, crossCheck=True)
 
    matches = bf.match(des1,des2)
 
    matches = sorted(matches, key = lambda x:x.distance)
    
    transformed = []
    
    for i in range(10):
        transformed.append(transformNum(matches[i]))

   # img3 = cv2.drawMatches(img1,kp1,img2,kp2,matches[:10],None,flags=2)
 
   # plt.imshow(img3,aspect='auto',interpolation='nearest'),plt.show()

    print(transformed)
    min_dictionary[name] = transformed[0]
    max_dictionary[name] = transformNum(tranmatches[len(matches)])
    everageOfDictionary[name] = sum(transformed)/len(matches)

# %%
def run(name,img):
    matchingInfo(makeImage(name))

# %%
makeImage(cv2.FONT_HERSHEY_DUPLEX)

# %%
cv2.imshow('image',makeImage(cv2.FONT_HERSHEY_DUPLEX))

# %%
matchingInfo(makeImage(cv2.FONT_HERSHEY_DUPLEX))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-121-defce4164e95> in <module>
# ----> 1 matchingInfo(makeImage(cv2.FONT_HERSHEY_DUPLEX))
#
# TypeError: matchingInfo() missing 1 required positional argument: 'path'

# %%
for i in range()
# Out:
# d
# 'd'

# %%
    img1 = cv2.imread(r'C:\Program Files\Tesseract-OCR\tesseract',0)
    img2 = img
    
    orb = cv2.ORB_create()
 
    kp1, des1 = orb.detectAndCompute(img1,None)
    kp2, des2 = orb.detectAndCompute(img2,None)
 
    bf = cv2.BFMatcher(cv2.NORM_HAMMING, crossCheck=True)
 
    matches = bf.match(des1,des2)
 
    matches = sorted(matches, key = lambda x:x.distance)
    
    transformed = []
    
    for i in matches:
        print(i)
        transformed.append(transformNum(i))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-105-46d1d7fc68b9> in <module>
#       1 img1 = cv2.imread(r'C:\Program Files\Tesseract-OCR\tesseract',0)
# ----> 2 img2 = img
#       3
#       4 orb = cv2.ORB_create()
#       5
#
# NameError: name 'img' is not defined

# %%
fontlist = ['cv2.FONT_HERSHEY_DUPLE', 'cv2.FONT_HERSHEY_TRIPLEX', 'cv2.FONT_ITALIC']
min_dictionary = {}
max_dictionary = {}
everageOfDictionary = {}

def makeImage(name):
    img_w = 300
    img_h = 200
    bpp = 3

    img = np.zeros((img_h, img_w, bpp), np.uint8)
    img.fill(255)

    black = (0,0,0)


    center_x = int(img_w / 2.0)
    center_y = int(img_h / 2.0)


    thickness = 1


    location = (center_x, center_y)
    font = name  # normal size serif font
    fontScale = 1.3
    cv2.putText(img, 'Dasom', location, font, fontScale, black, thickness)

    return img

# %%
def matchingInfo(img,path):
    img1 = cv2.imread(path,0)
    img2 = img
    
    orb = cv2.ORB_create()
 
    kp1, des1 = orb.detectAndCompute(img1,None)
    kp2, des2 = orb.detectAndCompute(img2,None)
 
    bf = cv2.BFMatcher(cv2.NORM_HAMMING, crossCheck=True)
 
    matches = bf.match(des1,des2)
 
    matches = sorted(matches, key = lambda x:x.distance)
    
    print(matches)
    
    transformed = []
    
    for i in range(10):
        transformed.append(transformNum(matches[i]))

   # img3 = cv2.drawMatches(img1,kp1,img2,kp2,matches[:10],None,flags=2)
 
   # plt.imshow(img3,aspect='auto',interpolation='nearest'),plt.show()
    return transformed

    min_dictionary[name] = transformed[0]
    max_dictionary[name] = transformNum(tranmatches[len(matches)])
    everageOfDictionary[name] = sum(transformed)/len(matches)

# %%
def run(name,path):
    goodImage = makeImage(name)
    transformed = matchingInfo(goodImage,path)
    min_dictionary[name] = transformed[0]
    max_dictionary[name] = transformed[len(transformed)-1]
    everageOfDictionary[name] = sum(transformed)/len(transformed)

# %%
name = cv2.FONT_HERSHEY_TRIPLEX
new_name = str(name)
print(new_name)
# Out:
# 4

# %%
run(cv2.FONT_HERSHEY_TRIPLEX,r'C:\Users\dlgpd\fontProject\itary.png')
# Out:
# [<DMatch 000001BE531F9B30>, <DMatch 000001BE531F92B0>, <DMatch 000001BE531F9D50>, <DMatch 000001BE531F9370>, <DMatch 000001BE531F90D0>, <DMatch 000001BE531F9A90>, <DMatch 000001BE531F91D0>, <DMatch 000001BE531F9490>, <DMatch 000001BE531F98D0>, <DMatch 000001BE531F9350>, <DMatch 000001BE531F9C70>, <DMatch 000001BE531F9090>, <DMatch 000001BE531F93B0>, <DMatch 000001BE531F9150>, <DMatch 000001BE531F9330>, <DMatch 000001BE531F9CF0>, <DMatch 000001BE531F9CD0>, <DMatch 000001BE531F9590>, <DMatch 000001BE531F9530>, <DMatch 000001BE531F97B0>, <DMatch 000001BE531F9410>, <DMatch 000001BE531F9570>, <DMatch 000001BE531F9A10>, <DMatch 000001BE531F92F0>, <DMatch 000001BE531F9210>, <DMatch 000001BE531F95D0>, <DMatch 000001BE531F97F0>, <DMatch 000001BE531F9A70>, <DMatch 000001BE531F9170>, <DMatch 000001BE531F9790>, <DMatch 000001BE531F98F0>, <DMatch 000001BE531F9D10>, <DMatch 000001BE531F9930>, <DMatch 000001BE531F9450>, <DMatch 000001BE531F98B0>, <DMatch 000001BE531F9870>, <DMatch 000001BE531F9C90>
# ...

# %%
print(max_dictionary)
# Out:
# {'': 1394577744, 4: 1394578256}

# %%
def play (path):
    for name in fontlist:
        run(name,path)

# %%
play(r'C:\Users\dlgpd\fontProject\itary.png')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-115-d7d12115329c> in <module>
# ----> 1 play(r'C:\Users\dlgpd\fontProject\itary.png')
#
# <ipython-input-114-7fb2fa8a3844> in play(path)
#       1 def play (path):
#       2     for name in fontlist:
# ----> 3         run(name,path)
#
# <ipython-input-108-34ea8636a3bc> in run(name, path)
#       1 def run(name,path):
# ----> 2     goodImage = makeImage(name)
#       3     transformed = matchingInfo(goodImage,path)
#       4     min_dictionary[name] = transformed[0]
#       5     max_dictionary[name] = transformed[len(transformed)-1]
#
# <ipython-input-94-5c08d989619c> in makeImage(name)
#      25     font = name  # normal size serif font
#      26     fontScale = 1.3
# ---> 27     cv2.putText(img, 'Dasom', location, font, fontScale, black, thickness)
#      28
#      29     return img
#
# ...
